# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo63-databost/blob/main/ProyectoFinal_Grupo63_Databost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Proyecto final**
# <h3> Andres Javier Galindo -- A01793927 </h3>
# <h3> Carlos Jesús Peñaloza Julio -- A01793931 </h3>

# %% [markdown]
# Metodologia Escogida para el proyecto : CRISP DM

# %% [markdown]
# ![1.CRISP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Fase 1**:
# <h3>Definicion de las necesidad del cliente, se enfoca a objetivos del proyecto y el plan preliminar</h3>
#
# ![2.CRISP.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo

# %% [markdown]
# **Fase 2**:
# <h3>Estudio y compresion de los datos </h3>
# la fase de entendimiento de datos comienza con la coleccion de datos inicial y continua con las actividades que permiten familiarizarse con los datos, identificar los problemas de calidad , descubrir conocimiento preliminar sobre los datos, y/o descubrir subconjuntos interesantes para formar hipotesis en cuanto a la informacion oculta
#
#
# ![3.CRISP-fase 2.jpg](data:image/jpeg;base64,...)
#
#
# ![3.CRISP-fase 2.1.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo

# %% [markdown]
# **Fase 3**:
# <h3>Definicion de las necesidad del cliente, se enfoca a objetivos del proyecto y el plan preliminar</h3>
#
# ![4.CRISP-fase 3.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo

# %% [markdown]
# **Fase 4**:
# <h3>Analisis de datos y seleccion de caracteristicas </h3>
#
# ![4.CRISP-fase 3.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo

# %% [markdown]
# **Fase 5**:
# <h3>Modelado </h3>
# Se selecciona y se aplica las tecnicas de modelado para que sea pertinente al problema ('modelos supervisados', 'Tablas de correlacion ', ETC....)
#
# ![5.CRISP-fase 4.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo

# %% [markdown]
# **Fase 6**:
# <h3>Evaluacion y puesta en produccion </h3>
# Evaluar el modelo a fondo y revisar los pasos ejecutados para crearlo, comparar el modelos obtenido con los objetivos de negocio. Un objetivo clave es determinar si hay alguna cuestion importante de negocio que no haya sido considerada suficientemente al final.
#
#
# ![6.CRISP-fase 5.jpg](data:image/jpeg;base64,...)

# %%
# espacio para incluir codigo
